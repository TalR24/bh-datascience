# %% [markdown]
# ## Multivariate OLS Regression
#
# This exercise will review the OLS model assumptions and also how to interpret regression results. We will add to the consumption/income bivariate OLS regression.

# %%
import numpy as np
import pandas as pd
import Haver
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm

# %%
Haver.path()

# %%
Haver.path('c:\DLX\dat')

# %%
df=Haver.data(["ypdhm","ch"] ,'us1plus', dates=True)

# %%
df.head()

# %%
df.dropna()

# %%
plt.scatter(df['logy'], df['logc'])
plt.xlabel('Real Disposable Personal Income')
plt.ylabel('Real Personal Consumption')
plt.show()

# %%
df['logc']=np.log(df['ch'])
df['logy']=np.log(df['ypdhm'])
df.dropna(inplace=True)

# %%
df

# %%
result = sm.ols(formula="df['logc']~ df['logy']", data=df).fit()

# %%
print(result.params)

# %%
print(result.summary())

# %%
resid=result.resid
plt.plot(resid)
