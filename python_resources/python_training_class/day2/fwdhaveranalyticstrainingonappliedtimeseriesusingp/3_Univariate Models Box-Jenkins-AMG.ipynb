# %% [markdown]
# ## Box-Jenkins Model
#
# This exercise will introduce to univariate models using the Box-Jenkins approach to modeling autoregressive prcoesses.

# %%
import numpy as np
import pandas as pd
import Haver
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
plt.style.use('seaborn')
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox as lb
from statsmodels.tsa.arima_model import ARIMA

# %%
Haver.path()

# %%
Haver.path('C:\\Users\\RNAMG01\\Desktop\\python haver training\\US1PLUS\\')

# %%
gdp=Haver.data(['gdph'] ,'us1plus', dates=True)

# %%
gdp.head()

# %%
gdp.count()

# %%
plt.plot(gdp)
plt.title('U.S. Real Gross Domestic Product')

# %%
lgdp=np.log(gdp)

# %%
plt.plot(lgdp)
plt.title('Natural Log U.S. Real Gross Domestic Product')

# %%
trend=range(0, 281)
trend

# %%
plt.plot(trend)

# %%
x=plot_acf(gdp, lags=50)
y=plot_pacf(gdp, lags=50)

# %%
lb_test=lb(lgdp, lags=25, boxpierce=False)
lb_test=np.array(lb_test)
lb_test=pd.DataFrame(lb_test)
lb_test=lb_test.transpose()
lb_test

# %%
#1
model = ARIMA(lgdp, order=(1,1,0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.gdph   No. Observations:                  286
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                 950.506
# Method:                       css-mle   S.D. of innovations              0.009
# Date:                Thu, 17 Jan 2019   AIC                          -1895.012
# Time:                        15:48:10   BIC                          -1884.044
# Sample:                    06-30-1947   HQIC                         -1890.615
#                          - 09-30-2018
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0077      0.001      9.614      0.000       0.006       0.009
# ar.L1.D.gdph     0.3605      0.055      6.537      0.000       0.252       0.469
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.7743           +0.0000j            2.7743            0.0000
# -----------------------------------------------------------------------------

# %%
#2
resids =(model_fit.resid[1:282])
resids.plot()

# %%
#3
x=plot_acf(resids, lags=50)
y=plot_pacf(resids, lags=50)

# %%
#4
lb_test=lb(resids, lags=25, boxpierce=False)
lb_test=np.array(lb_test)
lb_test=pd.DataFrame(lb_test)
lb_test=lb_test.transpose()
lb_test
# Out:
#             0         1
# 0    0.543399  0.461028
# 1    6.498025  0.038813
# 2    7.047643  0.070395
# 3    7.301463  0.120789
# 4   12.088670  0.033593
# 5   12.274651  0.056115
# 6   12.872123  0.075286
# 7   13.218449  0.104551
# 8   14.715481  0.099054
# 9   16.383025  0.089180
# 10  17.141942  0.103747
# 11  20.189729  0.063581
# 12  21.604848  0.061795
# 13  21.635047  0.086431
# 14  24.703828  0.054065
# 15  26.759575  0.044234
# 16  26.777849  0.061407
# 17  28.855066  0.050179
# 18  28.934498  0.067022
# 19  31.434944  0.049704
# 20  34.407166  0.032762
# 21  34.485413  0.043814
# 22  37.219714  0.030831
# 23  37.224199  0.041557
# 24  37.585733  0.050748

# %%
#1
model2 = ARIMA(lgdp, order=(2,1,0))
model_fit2 = model2.fit()
print(model_fit2.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.gdph   No. Observations:                  286
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                 952.344
# Method:                       css-mle   S.D. of innovations              0.009
# Date:                Thu, 17 Jan 2019   AIC                          -1896.688
# Time:                        15:49:07   BIC                          -1882.064
# Sample:                    06-30-1947   HQIC                         -1890.826
#                          - 09-30-2018
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0077      0.001      8.579      0.000       0.006       0.009
# ar.L1.D.gdph     0.3199      0.059      5.452      0.000       0.205       0.435
# ar.L2.D.gdph     0.1130      0.059      1.924      0.055      -0.002       0.228
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.8790           +0.0000j            1.8790            0.0000
# AR.2           -4.7108           +0.0000j            4.7108            0.5000
# -----------------------------------------------------------------------------

# %%
#2
resids2 =(model_fit2.resid[1:282])
resids2.plot()

# %%
#3
x=plot_acf(resids2, lags=50)
y=plot_pacf(resids2, lags=50)

# %%
#4
lb_test2=lb(resids2, lags=25, boxpierce=False)
lb_test2=np.array(lb_test2)
lb_test2=pd.DataFrame(lb_test2)
lb_test2=lb_test2.transpose()
lb_test2
# Out:
#             0         1
# 0    0.025848  0.872272
# 1    0.814995  0.665313
# 2    1.838419  0.606611
# 3    3.050041  0.549486
# 4    8.209163  0.145079
# 5    8.323608  0.215341
# 6    8.863810  0.262582
# 7    9.323329  0.315759
# 8   11.293530  0.256124
# 9   14.320452  0.158870
# 10  15.183549  0.174247
# 11  18.955109  0.089618
# 12  20.685835  0.079379
# 13  20.686153  0.109950
# 14  23.365504  0.076682
# 15  24.986895  0.070057
# 16  25.137547  0.091673
# 17  26.899283  0.080904
# 18  27.215680  0.099729
# 19  29.326200  0.081532
# 20  31.968502  0.058981
# 21  31.975134  0.077821
# 22  34.727189  0.055349
# 23  34.727276  0.072548
# 24  35.171762  0.085141

# %%
#1
model3 = ARIMA(lgdp, order=(3,1,0))
model_fit3 = model3.fit()
print(model_fit3.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.gdph   No. Observations:                  286
# Model:                 ARIMA(3, 1, 0)   Log Likelihood                 954.159
# Method:                       css-mle   S.D. of innovations              0.009
# Date:                Thu, 17 Jan 2019   AIC                          -1898.319
# Time:                        15:52:26   BIC                          -1880.039
# Sample:                    06-30-1947   HQIC                         -1890.992
#                          - 09-30-2018
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0077      0.001      9.586      0.000       0.006       0.009
# ar.L1.D.gdph     0.3331      0.059      5.676      0.000       0.218       0.448
# ar.L2.D.gdph     0.1491      0.061      2.432      0.016       0.029       0.269
# ar.L3.D.gdph    -0.1125      0.059     -1.912      0.057      -0.228       0.003
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.1001           -0.0000j            2.1001           -0.5000
# AR.2            1.7129           -1.1397j            2.0574           -0.0934
# AR.3            1.7129           +1.1397j            2.0574            0.0934
# -----------------------------------------------------------------------------

# %%
#2
resids3 =(model_fit3.resid[1:282])
resids3.plot()

# %%
#3
x=plot_acf(resids3, lags=50)
y=plot_pacf(resids3, lags=50)

# %%
#4
lb_test3=lb(resids3, lags=25, boxpierce=False)
lb_test3=np.array(lb_test3)
lb_test3=pd.DataFrame(lb_test3)
lb_test3=lb_test3.transpose()
lb_test3
# Out:
#             0         1
# 0    0.039385  0.842689
# 1    0.042813  0.978821
# 2    0.621652  0.891458
# 3    1.106098  0.893303
# 4    4.409725  0.492052
# 5    4.920145  0.554095
# 6    5.276092  0.626310
# 7    6.348368  0.608271
# 8    7.636445  0.571157
# 9   10.170713  0.425646
# 10  10.875912  0.453717
# 11  15.161379  0.232730
# 12  16.056483  0.246093
# 13  16.161755  0.303596
# 14  18.805326  0.222692
# 15  20.184610  0.212021
# 16  20.376954  0.255404
# 17  21.085146  0.275139
# 18  21.437085  0.313160
# 19  23.229436  0.277670
# 20  25.350489  0.232303
# 21  25.359933  0.280174
# 22  27.442632  0.237595
# 23  27.444659  0.284157
# 24  28.155748  0.300733

# %%
#1
model4 = ARIMA(lgdp, order=(4,1,0))
model_fit4 = model4.fit()
print(model_fit4.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.gdph   No. Observations:                  286
# Model:                 ARIMA(4, 1, 0)   Log Likelihood                 954.891
# Method:                       css-mle   S.D. of innovations              0.009
# Date:                Thu, 17 Jan 2019   AIC                          -1897.782
# Time:                        15:53:04   BIC                          -1875.846
# Sample:                    06-30-1947   HQIC                         -1888.989
#                          - 09-30-2018
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0077      0.001     10.282      0.000       0.006       0.009
# ar.L1.D.gdph     0.3252      0.059      5.520      0.000       0.210       0.441
# ar.L2.D.gdph     0.1603      0.062      2.590      0.010       0.039       0.282
# ar.L3.D.gdph    -0.0888      0.062     -1.436      0.152      -0.210       0.032
# ar.L4.D.gdph    -0.0715      0.059     -1.211      0.227      -0.187       0.044
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3219           -0.8986j            1.5984           -0.0950
# AR.2            1.3219           +0.8986j            1.5984            0.0950
# AR.3           -1.9433           -1.3041j            2.3403           -0.4059
# AR.4           -1.9433           +1.3041j            2.3403            0.4059
# -----------------------------------------------------------------------------

# %%
#2
resids4 =(model_fit4.resid[1:282])
resids4.plot()

# %%
#3
x=plot_acf(resids4, lags=50)
y=plot_pacf(resids4, lags=50)

# %%
#4
lb_test4=lb(resids4, lags=25, boxpierce=False)
lb_test4=np.array(lb_test4)
lb_test4=pd.DataFrame(lb_test4)
lb_test4=lb_test4.transpose()
lb_test4
# Out:
#             0         1
# 0    0.025345  0.873511
# 1    0.025348  0.987406
# 2    0.123002  0.988941
# 3    0.229620  0.993893
# 4    2.270295  0.810620
# 5    3.366375  0.761655
# 6    3.695739  0.814079
# 7    5.132613  0.743313
# 8    6.051396  0.734763
# 9    8.917995  0.539903
# 10   9.441032  0.581253
# 11  13.737512  0.317783
# 12  14.636056  0.330620
# 13  14.861215  0.387707
# 14  17.008649  0.318348
# 15  18.318168  0.305598
# 16  18.374001  0.365622
# 17  19.097859  0.385821
# 18  19.258806  0.440350
# 19  21.289855  0.380252
# 20  23.231841  0.331743
# 21  23.244588  0.388030
# 22  25.077206  0.346317
# 23  25.145140  0.397908
# 24  25.750646  0.421000

# %%
model = ARIMA(lgdp, order=(1,1,0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.gdph   No. Observations:                  286
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                 950.506
# Method:                       css-mle   S.D. of innovations              0.009
# Date:                Thu, 17 Jan 2019   AIC                          -1895.012
# Time:                        15:53:07   BIC                          -1884.044
# Sample:                    06-30-1947   HQIC                         -1890.615
#                          - 09-30-2018
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0077      0.001      9.614      0.000       0.006       0.009
# ar.L1.D.gdph     0.3605      0.055      6.537      0.000       0.252       0.469
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.7743           +0.0000j            2.7743            0.0000
# -----------------------------------------------------------------------------

# %%
resids =(model_fit.resid[1:282])
resids.plot()

# %%
x=plot_acf(resids, lags=50)
y=plot_pacf(resids, lags=50)

# %%
lb_test=lb(resids, lags=25, boxpierce=False)
lb_test=np.array(lb_test)
lb_test=pd.DataFrame(lb_test)
lb_test=lb_test.transpose()
lb_test
# Out:
#             0         1
# 0    0.543399  0.461028
# 1    6.498025  0.038813
# 2    7.047643  0.070395
# 3    7.301463  0.120789
# 4   12.088670  0.033593
# 5   12.274651  0.056115
# 6   12.872123  0.075286
# 7   13.218449  0.104551
# 8   14.715481  0.099054
# 9   16.383025  0.089180
# 10  17.141942  0.103747
# 11  20.189729  0.063581
# 12  21.604848  0.061795
# 13  21.635047  0.086431
# 14  24.703828  0.054065
# 15  26.759575  0.044234
# 16  26.777849  0.061407
# 17  28.855066  0.050179
# 18  28.934498  0.067022
# 19  31.434944  0.049704
# 20  34.407166  0.032762
# 21  34.485413  0.043814
# 22  37.219714  0.030831
# 23  37.224199  0.041557
# 24  37.585733  0.050748

# %%
model = ARIMA(lgdp, order=(1,0,0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                   gdph   No. Observations:                  287
# Model:                     ARMA(1, 0)   Log Likelihood                 854.232
# Method:                       css-mle   S.D. of innovations              0.012
# Date:                Thu, 17 Jan 2019   AIC                          -1702.464
# Time:                        15:53:08   BIC                          -1691.486
# Sample:                    03-31-1947   HQIC                         -1698.064
#                          - 09-30-2018
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.7269      1.098      7.950      0.000       6.575      10.878
# ar.L1.gdph     0.9999   8.56e-05   1.17e+04      0.000       1.000       1.000
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0001           +0.0000j            1.0001            0.0000
# -----------------------------------------------------------------------------

# %%
resids =(model_fit.resid[1:282])
resids.plot()

# %%
x=plot_acf(resids, lags=50)
y=plot_pacf(resids, lags=50)

# %%
lb_test=lb(resids, lags=25, boxpierce=False)
lb_test=np.array(lb_test)
lb_test=pd.DataFrame(lb_test)
lb_test=lb_test.transpose()
lb_test
# Out:
#             0             1
# 0   36.683801  1.389291e-09
# 1   51.267625  7.368460e-12
# 2   51.349632  4.120986e-11
# 3   52.413997  1.130123e-10
# 4   57.100485  4.821443e-11
# 5   57.424176  1.499086e-10
# 6   57.977894  3.819456e-10
# 7   58.043793  1.126131e-09
# 8   59.793950  1.468999e-09
# 9   62.412161  1.263350e-09
# 10  62.515190  3.150924e-09
# 11  66.306155  1.562095e-09
# 12  70.248555  7.224037e-10
# 13  71.163608  1.187143e-09
# 14  73.080538  1.255510e-09
# 15  73.871983  2.073684e-09
# 16  74.675587  3.329123e-09
# 17  77.980495  1.928696e-09
# 18  79.293714  2.460528e-09
# 19  80.790106  2.881677e-09
# 20  82.295928  3.325349e-09
# 21  83.055662  5.057514e-09
# 22  85.773968  3.599570e-09
# 23  85.847479  6.938061e-09
# 24  86.198631  1.181907e-08
